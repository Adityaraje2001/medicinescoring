# %%
import pandas as pd

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
train_df
# Out:
#      medicine_no  disease_type  \
# 0       MD-22117           677
# 1       MD-22118           121
# 2       MD-22119           200
# 3       MD-22120           455
# 4       MD-22121           404
# ...          ...           ...
# 9847    MD-31964           200
# 9848    MD-31965           166
# 9849    MD-31966           255
# 9850    MD-31967           521
# 9851    MD-31968            49
#
#                                         medicine_review  market_value  \
# 0     I read so many horrible reviews of this that I...            10
# 1     When I took the pill, I had a hard time rememb...             8
# 2     This is the only antidepressant that was  bene...             9
# 3     I took Alli for 2 months when it first came ou...             7
# 4     About ten days or two weeks after starting Est...            10
# ...                                                 ...           ...
# 9847  I&#039;ve only been using Brintellix for 1 wee...             9
# ...

# %%
test_df
# Out:
#      medicine_no  disease_type  \
# 0       MD-49997           555
# 1       MD-49998           472
# 2       MD-49999           308
# 3       MD-50000           352
# 4       MD-50001           121
# ...          ...           ...
# 3279    MD-53276           482
# 3280    MD-53277           240
# 3281    MD-53278            84
# 3282    MD-53279            98
# 3283    MD-53280           663
#
#                                         medicine_review  market_value  \
# 0     I came back from Cuba with a sinus infection a...            10
# 1     I just had my first injection both knees a few...            10
# 2     Doesn&#039;t work to lower blood pressure. I s...             2
# 3     TRAZODONE, gives nasty neck &amp; headaches to...             1
# 4     I was on this pill for 4 years. The side effec...             3
# ...                                                 ...           ...
# 3279  This medication is supposed to be continual pa...             4
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9852 entries, 0 to 9851
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   medicine_no      9852 non-null   object
#  1   disease_type     9852 non-null   int64
#  2   medicine_review  9852 non-null   object
#  3   market_value     9852 non-null   int64
#  4   launch_date      9852 non-null   object
#  5   score            9852 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 461.9+ KB

# %%
train_df['launch_year'] = pd.to_datetime(train_df['launch_date'], infer_datetime_format=True).dt.year
test_df['launch_year'] = pd.to_datetime(test_df['launch_date'], infer_datetime_format=True).dt.year
# Out:
# C:\Users\desai\AppData\Local\Temp\ipykernel_9368\1672744861.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   train_df['launch_year'] = pd.to_datetime(train_df['launch_date'], infer_datetime_format=True).dt.year
# C:\Users\desai\AppData\Local\Temp\ipykernel_9368\1672744861.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   train_df['launch_year'] = pd.to_datetime(train_df['launch_date'], infer_datetime_format=True).dt.year
# ...

# %%
test_df_medicine_no = test_df['medicine_no']
test_df_medicine_no
# Out:
# 0       MD-49997
# 1       MD-49998
# 2       MD-49999
# 3       MD-50000
# 4       MD-50001
#           ...
# 3279    MD-53276
# 3280    MD-53277
# 3281    MD-53278
# 3282    MD-53279
# 3283    MD-53280
# Name: medicine_no, Length: 3284, dtype: object

# %%
train_df= train_df.drop(columns=['launch_date','medicine_review','medicine_no'])
test_df= test_df.drop(columns=['launch_date','medicine_review','medicine_no'])

# %%
X_train = train_df.drop(columns=['score'])
y_train = train_df['score']
X_test = test_df

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
model = RandomForestRegressor(n_estimators=100)
linear_model = LinearRegression().fit(X_train,y_train)

# %%
model.fit(X_train,y_train)
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(X_test)
predictions_linear  = linear_model.predict(X_test)

# %%
predictions_linear
# Out:
# array([36.97753486, 30.51035873, 15.02425144, ..., 26.15187876,
#        36.42130953, 35.6883885 ])

# %%
predictions
# Out:
# array([22.35      , 31.55931746, 70.754     , ..., 32.66337746,
#        58.63866667, 25.6       ])

# %%
result_df = pd.DataFrame({
    'medicine_no' : test_df_medicine_no,
    'score' : predictions
})

# %%
result_df
# Out:
#      medicine_no      score
# 0       MD-49997  22.350000
# 1       MD-49998  31.559317
# 2       MD-49999  70.754000
# 3       MD-50000  17.253882
# 4       MD-50001   6.814035
# ...          ...        ...
# 3279    MD-53276  25.658556
# 3280    MD-53277  11.003811
# 3281    MD-53278  32.663377
# 3282    MD-53279  58.638667
# 3283    MD-53280  25.600000
#
# [3284 rows x 2 columns]

# %%
output_filename = 'test_scored.csv'

# %%
result_df.to_csv(output_filename,index=False)
result_df
# Out:
#      medicine_no      score
# 0       MD-49997  22.350000
# 1       MD-49998  31.559317
# 2       MD-49999  70.754000
# 3       MD-50000  17.253882
# 4       MD-50001   6.814035
# ...          ...        ...
# 3279    MD-53276  25.658556
# 3280    MD-53277  11.003811
# 3281    MD-53278  32.663377
# 3282    MD-53279  58.638667
# 3283    MD-53280  25.600000
#
# [3284 rows x 2 columns]
